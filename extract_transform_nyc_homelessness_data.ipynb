# %%
pip install sodapy
# Out:
# Requirement already satisfied: sodapy in /opt/anaconda3/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: requests>=2.28.1 in /opt/anaconda3/lib/python3.11/site-packages (from sodapy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.1->sodapy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.1->sodapy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.1->sodapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.28.1->sodapy) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml
import pandas as pd
from sodapy import Socrata

# %% [markdown]
# ### Using Socrata API to access 311 service requests

# %%
creds = yaml.load(open('credentials.yml'), Loader=yaml.FullLoader)
data_url='data.cityofnewyork.us'
data_set='erm2-nwe9'
app_token= creds['nyc_credentials']['app_token']
client = Socrata(data_url,app_token)
client.timeout = 60
results = client.get(data_set, where="Agency='DHS'and complaint_type='Encampment'",limit=10000) ## filtering for Encampment complaints to DHS
encampment_complaints = pd.DataFrame.from_records(results)

# %%
metadata = client.get_metadata(data_set)
[x['name'] for x in metadata['columns']]
# Out:
# ['Unique Key',
#  'Created Date',
#  'Closed Date',
#  'Agency',
#  'Agency Name',
#  'Complaint Type',
#  'Descriptor',
#  'Location Type',
#  'Incident Zip',
#  'Incident Address',
#  'Street Name',
#  'Cross Street 1',
#  'Cross Street 2',
#  'Intersection Street 1',
#  'Intersection Street 2',
#  'Address Type',
#  'City',
#  'Landmark',
#  'Facility Type',
#  'Status',
#  'Due Date',
#  'Resolution Description',
#  'Resolution Action Updated Date',
#  'Community Board',
#  'BBL',
#  'Borough',
#  'X Coordinate (State Plane)',
#  'Y Coordinate (State Plane)',
#  'Open Data Channel Type',
#  'Park Facility Name',
#  'Park Borough',
#  'Vehicle Type',
#  'Taxi Company Borough',
#  'Taxi Pick Up Location',
#  'Bridge Highway Name',
#  'Bridge Highway Direction',
#  'Road Ramp',
#  'Bridge Highway Segment',
#  'Latitude',
#  'Longitude',
#  'Location',
#  'Zip Codes',
#  'Community Districts',
#  'Borough Boundaries',
#  'City Council Districts',
#  'Police Precincts',
#  'Police Precinct']

# %%
encampment_complaints.head()
# Out:
#   unique_key             created_date agency                      agency_name  \
# 0   61236678  2024-05-22T23:37:26.000    DHS  Department of Homeless Services
# 1   61235332  2024-05-22T20:18:28.000    DHS  Department of Homeless Services
# 2   61232565  2024-05-22T20:12:02.000    DHS  Department of Homeless Services
# 3   61238027  2024-05-22T19:12:54.000    DHS  Department of Homeless Services
# 4   61239341  2024-05-22T18:12:53.000    DHS  Department of Homeless Services
#
#   complaint_type descriptor               location_type incident_zip  \
# 0     Encampment        N/A             Street/Sidewalk        10016
# 1     Encampment        N/A            Store/Commercial        11103
# 2     Encampment        N/A  Residential Building/House        10003
# 3     Encampment        N/A            Store/Commercial        11214
# 4     Encampment        N/A             Street/Sidewalk        10025
#
#       incident_address       street_name  ...            latitude  \
# 0  11 EAST   29 STREET  EAST   29 STREET  ...  40.744946414604016
# 1       47-07 BROADWAY          BROADWAY  ...  40.756280605364836
# 2    24 ST MARKS PLACE    ST MARKS PLACE  ...  40.728972240538575
# 3       2444 86 STREET         86 STREET  ...  40.598614479390086
# 4        2814 BROADWAY          BROADWAY  ...   40.80336985390443
#
#             longitude                                           location  \
# 0  -73.98597587253091  {'latitude': '40.744946414604016', 'longitude'...
# 1  -73.91325289282614  {'latitude': '40.756280605364836', 'longitude'...
# 2  -73.98857340070353  {'latitude': '40.728972240538575', 'longitude'...
# 3   -73.9883616460881  {'latitude': '40.598614479390086', 'longitude'...
# 4  -73.96726396631105  {'latitude': '40.80336985390443', 'longitude':...
#
#   resolution_action_updated_date closed_date resolution_description  \
# 0                            NaN         NaN                    NaN
# 1        2024-05-22T22:32:36.000         NaN                    NaN
# 2                            NaN         NaN                    NaN
# 3                            NaN         NaN                    NaN
# 4                            NaN         NaN                    NaN
#
#   bridge_highway_name road_ramp bridge_highway_segment  \
# 0                 NaN       NaN                    NaN
# 1                 NaN       NaN                    NaN
# 2                 NaN       NaN                    NaN
# 3                 NaN       NaN                    NaN
# 4                 NaN       NaN                    NaN
#
#   bridge_highway_direction
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 36 columns]

# %%
encampment_complaints["created_date"] = pd.to_datetime(encampment_complaints["created_date"]).dt.date

# %%
encampment_complaints.to_csv("encampment_complaints.csv", index=False)

# %%
aggregated_encampment_complaints = encampment_complaints.groupby('created_date')['unique_key'].nunique().reset_index()

# %%
 aggregated_encampment_complaints.columns = ['mon_year','encampment_complaints_by_month']

# %%
aggregated_encampment_complaints.to_csv("aggregated_encampment_complaints.csv", index=False)

# %%
# metadata = client.get_metadata(data_set)
# [x['name'] for x in metadata['columns']]
aggregated_encampment_complaints.head()
# Out:
#      mon_year  encampment_complaints_by_month
# 0  2023-05-10                               2
# 1  2023-05-11                              19
# 2  2023-05-12                              47
# 3  2023-05-13                              28
# 4  2023-05-14                              23

# %%
creds = yaml.load(open('credentials.yml'), Loader=yaml.FullLoader)
data_url='data.cityofnewyork.us'
data_set='k46n-sa2m'
app_token= creds['nyc_credentials']['app_token']
client = Socrata(data_url,app_token)
client.timeout = 60
results = client.get(data_set)
daily_dhs_report = pd.DataFrame.from_records(results)

# %%
daily_dhs_report.head()
# Out:
#             date_of_census total_adults_in_shelter total_children_in_shelter  \
# 0  2024-05-22T00:00:00.000                   53751                     32578
# 1  2024-05-21T00:00:00.000                   53799                     32612
# 2  2024-05-20T00:00:00.000                   53776                     32576
# 3  2024-05-19T00:00:00.000                   53739                     32555
# 4  2024-05-18T00:00:00.000                   53663                     32519
#
#   total_individuals_in_shelter single_adult_men_in_shelter  \
# 0                        86329                       15278
# 1                        86411                       15322
# 2                        86352                       15309
# 3                        86294                       15269
# 4                        86182                       15257
#
#   single_adult_women_in_shelter total_single_adults_in_shelter  \
# 0                          5019                          20297
# 1                          5016                          20338
# 2                          5009                          20318
# 3                          5012                          20281
# 4                          4983                          20240
#
#   families_with_children_in_shelter  \
# 0                             18927
# 1                             18942
# 2                             18937
# 3                             18934
# 4                             18914
#
#   adults_in_families_with_children_in_shelter  \
# 0                                       29504
# 1                                       29527
# 2                                       29515
# 3                                       29519
# 4                                       29489
#
#   children_in_families_with_children_in_shelter  \
# 0                                         32578
# 1                                         32612
# 2                                         32576
# 3                                         32555
# 4                                         32519
#
#   total_individuals_in_families_with_children_in_shelter_  \
# 0                                              62082
# 1                                              62139
# 2                                              62091
# 3                                              62074
# 4                                              62008
#
#   adult_families_in_shelter individuals_in_adult_families_in_shelter
# 0                      1834                                     3950
# 1                      1828                                     3934
# 2                      1831                                     3943
# 3                      1828                                     3939
# 4                      1826                                     3934

# %%
#change type from datetime to date
daily_dhs_report["date_of_census"] = pd.to_datetime(daily_dhs_report["date_of_census"]).dt.date

#change types in our dataframe from str to int to be able to manipulate and do calculations with
daily_dhs_report=daily_dhs_report.astype({"single_adult_men_in_shelter": int,
                               "total_adults_in_shelter": int,
                               "single_adult_women_in_shelter":int}
                              ,errors='raise')

# %%
# adding new columns to find the ratio per day of men and women at shelters
daily_dhs_report["avg_num_single_adult_men_in_shelter"] = daily_dhs_report["total_adults_in_shelter"]/daily_dhs_report["single_adult_men_in_shelter"]
daily_dhs_report["avg_num_single_adult_women_in_shelter"]= daily_dhs_report["total_adults_in_shelter"]/daily_dhs_report["single_adult_women_in_shelter"]

# %%
daily_dhs_report.head()
# Out:
#   date_of_census  total_adults_in_shelter total_children_in_shelter  \
# 0     2024-05-22                    53751                     32578
# 1     2024-05-21                    53799                     32612
# 2     2024-05-20                    53776                     32576
# 3     2024-05-19                    53739                     32555
# 4     2024-05-18                    53663                     32519
#
#   total_individuals_in_shelter  single_adult_men_in_shelter  \
# 0                        86329                        15278
# 1                        86411                        15322
# 2                        86352                        15309
# 3                        86294                        15269
# 4                        86182                        15257
#
#    single_adult_women_in_shelter total_single_adults_in_shelter  \
# 0                           5019                          20297
# 1                           5016                          20338
# 2                           5009                          20318
# 3                           5012                          20281
# 4                           4983                          20240
#
#   families_with_children_in_shelter  \
# 0                             18927
# 1                             18942
# 2                             18937
# 3                             18934
# 4                             18914
#
#   adults_in_families_with_children_in_shelter  \
# 0                                       29504
# 1                                       29527
# 2                                       29515
# 3                                       29519
# 4                                       29489
#
#   children_in_families_with_children_in_shelter  \
# 0                                         32578
# 1                                         32612
# 2                                         32576
# 3                                         32555
# 4                                         32519
#
#   total_individuals_in_families_with_children_in_shelter_  \
# 0                                              62082
# 1                                              62139
# 2                                              62091
# 3                                              62074
# 4                                              62008
#
#   adult_families_in_shelter individuals_in_adult_families_in_shelter  \
# 0                      1834                                     3950
# 1                      1828                                     3934
# 2                      1831                                     3943
# 3                      1828                                     3939
# 4                      1826                                     3934
#
#    avg_num_single_adult_men_in_shelter  avg_num_single_adult_women_in_shelter
# 0                             3.518196                              10.709504
# 1                             3.511226                              10.725478
# 2                             3.512705                              10.735875
# 3                             3.519484                              10.722067
# 4                             3.517271                              10.769215

# %%
daily_dhs_report.to_csv("daily_dhs_report.csv",index=False)

# %%
creds = yaml.load(open('credentials.yml'), Loader=yaml.FullLoader)
data_url='data.cityofnewyork.us'
data_set='3qem-6v3v'
app_token= creds['nyc_credentials']['app_token']
client = Socrata(data_url,app_token)
client.timeout = 60
results = client.get(data_set)
dhs_buildings = pd.DataFrame.from_records(results)

# %%
metadata = client.get_metadata(data_set)
[x['name'] for x in metadata['columns']]
# Out:
# ['Report Date',
#  'Borough',
#  'Community District',
#  'Adult Family Comm Hotel',
#  'Adult Family Shelter',
#  'Adult Shelter',
#  'Adult Shelter Comm Hotel',
#  'FWC Cluster',
#  'FWC Comm Hotel',
#  'FWC Shelter']

# %%
dhs_buildings.head()
# Out:
#                report_date   borough community_district adult_shelter  \
# 0  2024-04-30T00:00:00.000     Bronx                212             3
# 1  2024-04-30T00:00:00.000    Queens                414             1
# 2  2024-04-30T00:00:00.000    Queens                404           NaN
# 3  2024-04-30T00:00:00.000  Brooklyn                318           NaN
# 4  2024-04-30T00:00:00.000     Bronx                211           NaN
#
#   fwc_comm_hotel fwc_shelter adult_family_shelter adult_shelter_comm_hotel  \
# 0              4           3                  NaN                      NaN
# 1              3           1                    1                      NaN
# 2              1           1                  NaN                        1
# 3              1           3                    1                      NaN
# 4            NaN         NaN                  NaN                      NaN
#
#   adult_family_comm_hotel
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
dhs_buildings.fillna(0,inplace= True)

# %%
dhs_buildings.head()
# Out:
#                report_date   borough community_district adult_shelter  \
# 0  2024-04-30T00:00:00.000     Bronx                212             3
# 1  2024-04-30T00:00:00.000    Queens                414             1
# 2  2024-04-30T00:00:00.000    Queens                404             0
# 3  2024-04-30T00:00:00.000  Brooklyn                318             0
# 4  2024-04-30T00:00:00.000     Bronx                211             0
#
#   fwc_comm_hotel fwc_shelter adult_family_shelter adult_shelter_comm_hotel  \
# 0              4           3                    0                        0
# 1              3           1                    1                        0
# 2              1           1                    0                        1
# 3              1           3                    1                        0
# 4              0           0                    0                        0
#
#   adult_family_comm_hotel
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %%
#change date and time column to just date YYYY-MM-DD format
dhs_buildings["report_date"]=pd.to_datetime(dhs_buildings["report_date"]).dt.date

# %%
dhs_buildings.to_csv("dhs_buildings.csv",index=False)
